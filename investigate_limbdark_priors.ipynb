# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import corner

# %%
PRIMARY_DIR = "/Users/research/projects/alderaan/"
LIMBDARK_DIR = PRIMARY_DIR + "Limbdark_priors/"

filelist = np.sort(glob.glob(LIMBDARK_DIR + "*.ld"))
filelist = np.random.choice(filelist, 5, replace=False)

for file in filelist:
    rawdata = np.loadtxt(file, skiprows=1, usecols=[1,2,3,4,5]).swapaxes(0,1)

    data = {}
    keys = "Teff logg FeH u1 u2".split()

    for i, k in enumerate(keys):
        data[k] = rawdata[i]
        
    #data["q1"] = (data["u1"] + data["u2"])**2
    #data["q2"] = 0.5*data["u1"]/(data["u1"] + data["u2"])
        
    corner.corner(data);
