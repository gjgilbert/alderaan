# %%
# !mprof run --include-children python main_pipeline.py --target='K00137' --mission='Kepler' --primary_dir='/Users/research/projects/archeopteryx/' --csv_file='/Users/research/projects/archeopteryx/Catalogues/clean_kepler_catalog.csv'
# !mprof plot --output memory-profile.png
# Out:
# mprof: Sampling memory every 0.1s
# Reading in data from csv file
# Initializing 3 Planet objects
# Making transit masks
# Setting dummy values for GP priors
#
#
# cumulative runtime =  52 s
#
#
# (1) Fitting POLYNOMIAL TTV model
# optimizing logp for variables: [logvar, flux0]
# 48it [00:09,  5.26it/s, logp=1.531348e+06]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1506043.2223676904 -> 1531348.2307259487
# optimizing logp for variables: [b, logr, Rstar]
# 146it [00:24,  5.55it/s, logp=1.518309e+06]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1506043.2223676904 -> 1518309.3732337381
# optimizing logp for variables: [Mstar, u]
# 22it [00:03,  5.72it/s, logp=1.518324e+06]
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1518309.3732337381 -> 1518323.7184125187
# optimizing logp for variables: [C1, C0]
# 57it [00:11,  4.99it/s, logp=1.518395e+06]
# ...

# %%
# Out:
# Using last profile data.
